# %%
import matplotlib
import matplotlib.pyplot as plt

from Env.Simulator_New import Simulator
from utils import Visualiser
env = Simulator()
# %load_ext autoreload
# Out:
# TODO: make action of 0 end episode (Submit design)

# %%
# %reload_ext autoreload

# %%
env.reset()
for i in range(env.split_option_n):
    selected_stream = env.n_outlet_streams - 1
    selected_compound = i
    discrete_action = selected_stream*env.split_option_n + selected_stream
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])

performance_ordered = env.Performance_metric
sequence_1 = env.sep_order
print(f'Performance metric sep by lightness is {performance_ordered}')

BFD1 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD1)
# Out:
# Performance metric sep by lightness is [1677.66685017]

# %%
env.reset()
flowrated_order = [2, 1, 4, 0, 3]
sep_order = [0, 0, 1, 0, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_stream
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')

BFD2 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD2)
# Out:
# Performance metric sep by flowrate is [2850.27453618]

# %%
env.reset()
flowrated_order = [0, 4, 2, 1, 3]
sep_order = [0, 1, 1, 1, 3]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_stream
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
# Out:
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:109: RuntimeWarning: invalid value encountered in double_scalars
#   LK_B = bots[Light_Key] / bots.sum()
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:110: RuntimeWarning: invalid value encountered in double_scalars
#   HK_B = bots[Heavy_Key] / bots.sum()
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:243: RuntimeWarning: invalid value encountered in true_divide
#   bots_composition = bots/bots.sum()
# C:\Users\meatrobot\Anaconda3\envs\DRL\lib\site-packages\scipy\optimize\minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:136: RuntimeWarning: invalid value encountered in double_scalars
#   n_stages_min = np.log(LK_D/(HK_D) * HK_B/LK_B)/np.log(relative_volatility_mean)
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   /(relative_volatility_mean - 1)
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Sizing\dc_capital_cost.py:81: RuntimeWarning: invalid value encountered in greater_equal
#   if N >= 20:
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:157: RuntimeWarning: invalid value encountered in greater
#   if Length > 170 or Diameter > 17:  # limiting thresholds (would require custom column)
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\Env\Simulator_New.py:175: RuntimeWarning: invalid value encountered in true_divide
#   purity = max(np.divide(stream, stream.sum()))
# D:\Github\RL-Process-Design\Discrete and Continuous\Heuristic Design\utils.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   purity = 100 * stream.max() / stream.sum()
# Performance metric sep by flowrate is [nan]

# %%
env.
