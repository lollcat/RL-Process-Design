# %%
import matplotlib
import matplotlib.pyplot as plt

from Env.Simulator_New import Simulator
from Utils.utils import Visualiser
env = Simulator()

# %% [markdown]
# ## Solution 1 Standard-PDQN

# %%
env.reset()
flowrated_order = [0, 0, 4, 2, 3]
sep_order = [0, 1, 2, 2, 4]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i] # ignore flowrated ordr, this is LK selection
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/1.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.64816013]
# Performance metric2 sep by lightness is [7.22874191]
# Revenue is 74.92352754956626
# Capital cost is [26.3610845]
# [1.3720144114642854, 39.249741381169045, 18.486090829365143, 15.815680927567783]
# [1.5417022419824347, 0.4172070756203743, 2.262746364826231, 1.9562187432817457, 20.18321007537643]

# %% [markdown]
# ## Solution 2 with freeze

# %%
env.reset()
flowrated_order = [0, 4, 4, 4, 4] # ignore flowrated ordr, this is LK selection
sep_order = [0, 1, 1, 1, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/2.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.73849375]
# Performance metric2 sep by lightness is [3.95902599]
# Revenue is 40.65337096865344
# Capital cost is [10.63111072]
# [1.3720144114642854, 39.249741381169045, 0.015815144619820014, 0.015800031400285255]
# [1.5417022419824347, 2.263118837067464, 2.2947791866131957, 2.265874630450806, 2.2656358194770236]

# %% [markdown]
# ## Solution 3: With dueling

# %%
env.reset()
flowrated_order = [0, 0, 0, 4, 0] # ignore flowrated ordr, this is LK selection
sep_order = [0, 1, 1, 2, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/3b.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.87390264]
# Performance metric2 sep by lightness is [4.01315041]
# Revenue is 40.6440143543556
# Capital cost is [5.1251028]
# [1.3720144114642854, 0.001369281375987476, 0.02088928034628235, 39.249741381169045]
# [1.5417022419824347, 0.4172070756203743, 0.4264659670659567, 2.262746364826231, 0.4769811463775416]

# %% [markdown]
# ## Solution 4 With allow submit

# %%
env.reset()
flowrated_order = [4] # ignore flowrated ordr, this is LK selection
sep_order = [0]
for i in range(1):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(1)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/4.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is 0
# Performance metric2 sep by lightness is 0
# Revenue is 0.0
# Capital cost is [2.57724347]
# []
# [2.5772434684863006]

# %% [markdown]
# # Solution baseline reward 2

# %%
env.reset()
flowrated_order = [2, 1, 4, 2, 3] # ignore flowrated ordr, this is LK selection
sep_order = [0, 0, 1, 1, 4]
continuous_actions = [0.4673, -1, 1, 1, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = continuous_actions[i]
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/5.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.65600974]
# Performance metric2 sep by lightness is [7.07425662]
# Revenue is 73.26273290574572
# Capital cost is [25.20166661]
# [0.7095352850182568, 39.249741381169045, 17.48777531199063, 15.815680927567783]
# [1.4447189123230348, 1.802080525655657, 1.5187707985983916, 0.8650193566422011, 19.57107701859633]

# %% [markdown]
# ## Improved Baseline 2

# %%
env.reset()
flowrated_order = [2, 0, 3, 1, 4] # ignore flowrated ordr, this is LK selection
sep_order = [0, 0, 1, 2, 3]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/BFD_configs/6.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.57992422]
# Performance metric2 sep by lightness is [10.43623679]
# Revenue is 108.93861536001405
# Capital cost is [45.76247425]
# [1.3720144114642854, 18.486090829365143, 20.88955049302443, 15.815680299490193, 13.125537945500954, 39.249741381169045]
# [2.28443235131818, 1.5078214309107516, 20.519119667637725, 20.016226977491215, 1.43487382528094]
