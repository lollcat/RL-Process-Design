# %%
import matplotlib
import matplotlib.pyplot as plt

from Env.Simulator_New import Simulator
from Utils.utils import Visualiser
env = Simulator()
# Out:
# TODO: make action of 0 end episode (Submit design)

# %% [markdown]
# ## Heuristic 1: Seperation by Lightness

# %%
env.reset()
for i in range(env.split_option_n):
    selected_stream = env.n_outlet_streams - 1
    selected_compound = i
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = -1
    action = ()
    env.step([continuous_action, discrete_action])

performance_ordered = env.Performance_metric
sequence_1 = env.sep_order
print(f'Performance metric sep by lightness is {performance_ordered}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD1 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD1)
ax.axis("off")
fig.savefig("Data_Plots/sep_lightness_BFD.png", bbox_inches='tight')
# Out:
# Performance metric sep by lightness is [-6909741.83089272]
# Performance metric2 sep by lightness is [-0.06909752]
# Revenue is 0.0
# Capital cost is [6.90975183]
# []
# [1.0112991343208573, 1.9393526857923917, 1.1792709912960642, 1.842649506088688, 0.9371795133947158]

# %%
env.column_dimensions
# Out:
# [[array([6.11494097]), 30.829678238640167],
#  [array([30.33269506]), 125.95150140455156],
#  [array([6.84414737]), 2.574565993208119],
#  [array([31.38074572]), 63.96699633288422],
#  [array([7.44253776]), 0.6326172835968021]]

# %%
[env.capital_cost[i]/1e6 for i in range(5)], env.revenue*8000/1e6
# Out:
# ([array([2.16423799]),
#   array([24.05768128]),
#   array([2.72720095]),
#   array([23.8088548]),
#   array([1.99213955])],
#  871508.924276452)

# %%
env.reset()
flowrated_order = [2, 1, 4, 0, 3]
sep_order = [0, 0, 1, 0, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by flowrate is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')

BFD2 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.axis("off")
ax.imshow(BFD2)
fig.savefig("Data_Plots/sep_flowrate_BFD.png", bbox_inches='tight')
# Out:
# Performance metric sep by flowrate is [9.05060581]
# Performance metric2 sep by lightness is [9.85960468]

# %%
env.reset()
flowrated_order = [0, 4, 2, 1, 3]
sep_order = [0, 1, 1, 1, 3]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_3 = env.sep_order
print(f'Performance metric sep by rel vol is {performance_flowrate}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/sep_volatility.png", bbox_inches='tight')
# Out:
# Performance metric sep by rel vol is [9.49492185]
# Performance metric2 sep by lightness is [10.34363645]

# %%
# this is just for graphic used in report
env.reset()
flowrated_order = [2, 1, 4]
sep_order = [0, 0, 1]
for i in range(3):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])

BFD_ = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD_)
ax.axis("off")
fig.savefig("Data_Plots/BFD_example.png", bbox_inches='tight', bbox_inches='tight')

print(env.stream_table[3].round(2))
print(env.stream_table[4].round(2))
print(env.stream_table[5].round(2))
print(env.stream_table[6].round(2))
