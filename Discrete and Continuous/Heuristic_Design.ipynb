# %%
import matplotlib
import matplotlib.pyplot as plt

from Env.Simulator_new_reward import Simulator as Simulator1
from Env.Simulator_New import Simulator
from Utils.utils import Visualiser
env = Simulator()
env2 = Simulator1()

# %% [markdown]
# ## Heuristic 1: Seperation by Lightness

# %%
env.reset()
for i in range(env.split_option_n):
    selected_stream = env.n_outlet_streams - 1
    selected_compound = i
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])

performance_ordered = env.Performance_metric
sequence_1 = env.sep_order
print(f'Performance metric sep by lightness is {performance_ordered}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD1 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD1)
ax.axis("off")
fig.savefig("Data_Plots/Heuristics/sep_lightness_BFD.png", bbox_inches='tight')
# Out:
# Performance metric sep by lightness is [9.57710821]
# Performance metric2 sep by lightness is [10.4331691]
# Revenue is 108.9386155345565
# Capital cost is [46.06924571]
# [1.3720144114642854, 20.88955049302443, 13.125538120043426, 18.486090829365143, 15.815680299490193, 39.249741381169045]
# [1.5417022419824347, 20.67617673161069, 1.8978864700876297, 20.518606443236997, 1.43487382528094]

# %%
env.reset()
flowrated_order = [2, 1, 4, 0, 3]
sep_order = [0, 0, 1, 0, 1]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_2 = env.sep_order
print(f'Performance metric sep by lightness is {performance_ordered}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD2 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.axis("off")
ax.imshow(BFD2)
fig.savefig("Data_Plots/Heuristics/sep_flowrate_BFD.png", bbox_inches='tight')
# Out:
# Performance metric sep by lightness is [9.57710821]
# Performance metric2 sep by lightness is [10.12371856]
# Revenue is 108.93861571127857
# Capital cost is [77.01430144]
# [1.3720144114642854, 18.486090829365143, 13.125537945500954, 39.249741381169045, 20.889550216211365, 15.815680927567783]
# [2.28443235131818, 51.54796653034433, 1.4563020605764672, 1.5423904243832176, 20.18321007537643]

# %%
env.reset()
flowrated_order = [0, 4, 2, 1, 3]
sep_order = [0, 1, 1, 1, 3]
for i in range(env.split_option_n):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])
performance_flowrate = env.Performance_metric
sequence_3 = env.sep_order
print(f'Performance metric sep by lightness is {performance_ordered}')
print(f'Performance metric2 sep by lightness is {env.Performance_metric2}')
print(f'Revenue is {env.revenue/1e6}')
print(f'Capital cost is {sum(env.capital_cost)/1e6}')
print([env.revenue_by_stream[i]/1e6 for i in range(len(env.revenue_by_stream))])
print([env.capital_cost[i][0]/1e6 for i in range(5)])

BFD3 = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD3)
ax.axis("off")
fig.savefig("Data_Plots/Heuristics/sep_volatility.png", bbox_inches='tight')
# Out:
# Performance metric sep by lightness is [9.57710821]
# Performance metric2 sep by lightness is [10.43425249]
# Revenue is 108.93861598809163
# Capital cost is [45.9609107]
# [1.3720144114642854, 20.88955049302443, 39.249741381169045, 18.486090829365143, 13.125537945500954, 15.815680927567783]
# [1.5417022419824347, 2.263118837067464, 1.956652568530664, 20.016226977491215, 20.18321007537643]

# %%
# this is just for graphic used in report
env.reset()
flowrated_order = [2, 1, 4]
sep_order = [0, 0, 1]
for i in range(3):
    selected_stream = sep_order[i]
    selected_compound = flowrated_order[i]
    discrete_action = selected_stream*env.split_option_n + selected_compound 
    continuous_action = 1
    action = ()
    env.step([continuous_action, discrete_action])

BFD_ = Visualiser(env).visualise()
matplotlib.rcParams['figure.dpi']= 800
fig, ax = plt.subplots()
ax.imshow(BFD_)
ax.axis("off")
fig.savefig("Data_Plots/BFD_example.png", bbox_inches='tight', bbox_inches='tight')

print(env.stream_table[3].round(2))
print(env.stream_table[4].round(2))
print(env.stream_table[5].round(2))
print(env.stream_table[6].round(2))
# Out:
#   File "<ipython-input-10-96ef814fb8f6>", line 18
#     fig.savefig("Data_Plots/BFD_example.png", bbox_inches='tight', bbox_inches='tight')
#                                                                   ^
# SyntaxError: keyword argument repeated
